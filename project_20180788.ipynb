# %% [markdown]
# ## 간단한 구조의 RNN을 이용한 텍스트 생성

# %%
import numpy as np
# import cupy as np  # GPU를 사용하면 주석 해제
import matplotlib.pyplot as plt

# -- 각 설정값 --
n_time = 20 # 시점의 수
n_mid = 128 # 은닉층 뉴런 수
eta = 0.01 # 학습률
clip_const = 0.02 # 노름의 최댓값을 구하는 상수
beta = 2 # 확률분포 폭（다음 시점의 문자를 예측할 때 사용
epoch = 60
batch_size = 128

def sigmoid(x):
    return 1/(1+np.exp(-x))

def clip_grad(grads, max_norm):
    norm = np.sqrt(np.sum(grads*grads))
    r = max_norm / norm
    if r < 1:
        clipped_grads = grads * r
    else:
        clipped_grads = grads
    return clipped_grads

# -- 훈련용 텍스트 --
with open("human_problem.txt", mode="r", encoding="utf-8-sig") as f:  # 파일 읽어들이기
    text = f.read()
print("문자수:", len(text))   # len()으로 문자열의 문자 수도 출력 가능

# -- 문자와 인덱스 연결 --
chars_list = sorted(list(set(text)))  # set으로 문자 중복 제거
n_chars = len(chars_list)
print("문자 수（중복없음）:", n_chars)

char_to_index = {}   # 문자가 키이고 인덱스가 값인 딕셔너리
index_to_char = {}   # 인덱스가 키이고 문자가 값인 딕셔너리
for i, char in enumerate(chars_list):
    char_to_index[char] = i
    index_to_char[i] = char
 
# -- 시계열로 나열된 문자와 다음 차례 문자 --
seq_chars = []
next_chars = []
for i in range(0, len(text) - n_time):
    seq_chars.append(text[i: i + n_time])
    next_chars.append(text[i + n_time])

# -- 입력과 정답 원핫 인코딩으로 표시 --
input_data = np.zeros((len(seq_chars), n_time, n_chars), dtype=np.uint8)
correct_data = np.zeros((len(seq_chars), n_chars), dtype=np.uint8)
for i, chars in enumerate(seq_chars):
    correct_data[i, char_to_index[next_chars[i]]] = 1  # 정답을 원핫 인코딩으로 표시
    for j, char in enumerate(chars):
        input_data[i, j, char_to_index[char]] = 1  # 입력을 원핫 인코딩으로 표시

# -- RNN층 --
class SimpleRNNLayer:
    def __init__(self, n_upper, n):
       # 파라미터 초깃값
        self.w = np.random.randn(n_upper, n) / np.sqrt(n_upper)  # 자비에르 초깃값
        self.v = np.random.randn(n, n) / np.sqrt(n)  # 자비에르 초깃값
        self.b = np.zeros(n)

    def forward(self, x, y_prev):  # y_prev: 이전 시점의 출력
        u = np.dot(x, self.w) + np.dot(y_prev, self.v) + self.b
        self.y = np.tanh(u)  # 출력
    
    def backward(self, x, y, y_prev, grad_y):
        delta = grad_y * (1 - y**2)

        # 각 기울기
        self.grad_w += np.dot(x.T, delta)
        self.grad_v += np.dot(y_prev.T, delta)
        self.grad_b += np.sum(delta, axis=0)

        self.grad_x = np.dot(delta, self.w.T)
        self.grad_y_prev = np.dot(delta, self.v.T)

    def reset_sum_grad(self):
        self.grad_w = np.zeros_like(self.w)
        self.grad_v = np.zeros_like(self.v)
        self.grad_b = np.zeros_like(self.b)

    def update(self, eta):
        self.w -= eta * self.grad_w
        self.v -= eta * self.grad_v
        self.b -= eta * self.grad_b

    def clip_grads(self, clip_const):
        self.grad_w = clip_grad(self.grad_w, clip_const*np.sqrt(self.grad_w.size))
        self.grad_v = clip_grad(self.grad_v, clip_const*np.sqrt(self.grad_v.size))

# -- 전결합 출력층 --
class OutputLayer:
    def __init__(self, n_upper, n):
        self.w = np.random.randn(n_upper, n) / np.sqrt(n_upper)  # 자비에르 초깃값
        self.b = np.zeros(n)

    def forward(self, x):
        self.x = x
        u = np.dot(x, self.w) + self.b
        self.y = np.exp(u)/np.sum(np.exp(u), axis=1).reshape(-1, 1)  # 소프트맥스 함수

    def backward(self, t):
        delta = self.y - t
        
        self.grad_w = np.dot(self.x.T, delta)
        self.grad_b = np.sum(delta, axis=0)
        self.grad_x = np.dot(delta, self.w.T) 

    def update(self, eta):
        self.w -= eta * self.grad_w
        self.b -= eta * self.grad_b

# -- 각 층의 초기화 --
rnn_layer = SimpleRNNLayer(n_chars, n_mid)
output_layer = OutputLayer(n_mid, n_chars)

# -- 훈련 --
def train(x_mb, t_mb):
    # 순전파 RNN층
    y_rnn = np.zeros((len(x_mb), n_time+1, n_mid))
    y_prev = y_rnn[:, 0, :]
    for i in range(n_time):
        x = x_mb[:, i, :]
        rnn_layer.forward(x, y_prev)
        y = rnn_layer.y
        y_rnn[:, i+1, :] = y
        y_prev = y

    # 순전파 출력층
    output_layer.forward(y)

    # 역전파 출력층 
    output_layer.backward(t_mb)
    grad_y = output_layer.grad_x

    # 역전파 출력층
    rnn_layer.reset_sum_grad()
    for i in reversed(range(n_time)):
        x = x_mb[:, i, :]
        y = y_rnn[:, i+1, :]
        y_prev = y_rnn[:, i, :]
        rnn_layer.backward(x, y, y_prev, grad_y)
        grad_y = rnn_layer.grad_y_prev

    # 파라미터 갱신
    rnn_layer.clip_grads(clip_const)
    rnn_layer.update(eta)
    output_layer.update(eta)

# -- 순전파 --
def predict(x_mb):
    # 순전파 RNN층
    y_prev = np.zeros((len(x_mb), n_mid))
    for i in range(n_time):
        x = x_mb[:, i, :]
        rnn_layer.forward(x, y_prev)
        y = rnn_layer.y
        y_prev = y

   # 순전파 출력층
    output_layer.forward(y)
    return output_layer.y

# -- 오차 계산 --
def get_error(x, t):
    limit = 1000
    if len(x) > limit:  # 측정 샘플 수 최댓값 설정
        index_random = np.arange(len(x))
        np.random.shuffle(index_random)
        x = x[index_random[:limit], :]
        t = t[index_random[:limit], :]
    y = predict(x)
    return -np.sum(t*np.log(y+1e-7))/batch_size  # # 교차 엔트로피오차

def create_text():
    prev_text = text[0:n_time]  # 입력
    created_text = prev_text  # # 생성되는 텍스트
    print("Seed:", created_text)

    for i in range(200):  # 2200자 문장 생성
       # 입력을 원핫 인코딩으로 표시
        x = np.zeros((1, n_time, n_chars))
        for j, char in enumerate(prev_text):
            x[0, j, char_to_index[char]] = 1
        
       # 다음 문자 예측
        y = predict(x)
        p = y[0] ** beta  # 확률분포 조정
        p = p / np.sum(p)   # p의 합을 1로
        next_index = np.random.choice(len(p), size=1, p=p)
        next_char = index_to_char[int(next_index[0])]
        created_text += next_char
        prev_text = prev_text[1:] + next_char

    print(created_text)
    print()  # 개행

error_record = []
n_batch = len(input_data) // batch_size  # 1# 1에포크당 배치 개수
for i in range(epoch):
        
    # -- 학습 -- 
    index_random = np.arange(len(input_data))
    np.random.shuffle(index_random)  #  # 인덱스 임의 섞기
    for j in range(n_batch):
        
        # 미니 배치 구성
        mb_index = index_random[j*batch_size : (j+1)*batch_size]
        x_mb = input_data[mb_index, :]
        t_mb = correct_data[mb_index, :]
        train(x_mb, t_mb)

        # -- 경과 표시 -- 
        print("\rEpoch: "+str(i+1)+"/"+str(epoch)+"  "+str(j+1)+"/"+str(n_batch), end="")

   # -- 오차 계산 --
    error = get_error(input_data, correct_data)
    error_record.append(error)
    print("  Error: "+str(error))

 # -- 경과 표시 --
    create_text()

plt.plot(range(1, len(error_record)+1), error_record, label="error")
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.legend()
plt.show()
# Out:
# 문자수: 60322
# 문자 수（중복없음）: 980
# Epoch: 1/60  471/471  Error: 36.26186598158994
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇하는 선기을 물라지며. 저리며는 것까간는 한지지지. 그리는 붙으나서 것는 것는 기었던 돌으을 것는 것는 일아한는 것는 물하나며,,이이는 것을 것을 눈게는 것는 것리는 것음는 무으을 누비야으나지는 물는 지리를 것호을 것렇하는 것지을 들는 것는 것을 것머는 바으라 일는 것었는 지을?지새 것리는 것서기지, 바째는 돌었니는 것는 것을 것을에 억기는 것으지게 주었던
#
# Epoch: 2/60  471/471  Error: 29.838172514727773
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇 하고 하아도 하고 이 분은 들어 나가 이 못 하였다. 그리고 하려 말 하는 들어서 들어 하고 하았다. 그래 것하였다. 그리고 하고 따하니 하비 하지 나기다. 그리고 하여 없에 첫시 말리고 하에 들어 어머니 바을 이 오 그리고 불비  그리고 들어 않는 모하였 하금 일 사 이 놀 오 하았다.
# 선비는 하시  아으로 하고 하고 나리지 가 이 가 이 앞 사 하으
#
# Epoch: 3/60  471/471  Error: 27.826852370301154
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 저은 선비는 머하는 머리를 선비는 것을 것이다. 그철이는 너어서 그는 신철이는 이 집을 하고 놓이 물이서 그의 이다.
# 이 방으로 사근이다. 그래고 것이다. 그는 손이 사리고 생고 신다. 그래고 그의 것이다. 그리고 자었다. 그리고 넘어나 그는 사이 조었다. 그는 모아이다.
# 그는 듯이 주리고 선비는 이서게 얼도 생서 다고 말이 계고 하고 하고 것이다. 그
#
# Epoch: 4/60  471/471  Error: 26.761866698802834
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 사호는 여이 같이서 무지 있는 것이 어머니는 선비는 일이 일어 놓고 저 주고 소리가 그는 생각 일어나 문을 다고 그의 일어서 조어 신을 가 일어 다는 것이 어머니는 것이다. 그는 어머니. 덕부는 물을 보고 것을 무 못어 웃는 물을 선비는 옥점이는 것을 바라보았다. 그리고 대는 것을 보고 어머니 눈이 말에 어머니는 무시 오는 못하였다. 그는 무슨 있는 것
#
# Epoch: 5/60  471/471  Error: 26.402935099094606
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 들어 보며 생각하였다. 이서방은 그가 들어서 들어 보았다. 그리고 오작을 하고 놓개 것이 그의 생각을 되려 자의 것이 놈한 들이 있는 것이 방정 들을 들은 것이 하고 들어 말이 물이 들어 들어 오는 것을 바라보았다. 그리고 한 안을 돌아보았다. 그리고 그의 말을 가 하고 하여 하였다. 그러나 그의 어머니를 백 속이 못 따방 하여 보았다. 그리고 자
#
# Epoch: 6/60  471/471  Error: 25.208506605960174
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 소리를 내 오는 것을 보이 뒤리를 때 그는 물어 밤 따라 그는 모점 가 양을 내 말을 하였다. 그는 어머니는 좀 동아 있는 것이 듯이 한 수가 가 아 말을 하는 어서 말을 보우가 그의 계자리는 것을 하였다. 그는 무슨 집을 가는 그 말이 방자 말 만나 그가 무기 볼 들어 못 저 위에 그의 손으로 선비는 음을 내라 그 아 가 그는 그의 안에 그리 그 음
#
# Epoch: 7/60  471/471  Error: 23.899009098390522
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하는 것을 나무다.
# 한 방은 이 방에 섰다.
# 이서방은 소리에 선비는 아보니 어디 있리고 나도 때에 첫째는 불양이 이나 일어 보니, 선비를 보고 나무다. 그리고 사람에 들어서 소리를 바라보며,
# 아, 아무 집에 것은 입에서 이 방간에 가 아리를 하였다.
# 이 방은 이 차래 가지 못하였다.
# 이렇게 해 아러지 않으로 들어 보는 것이다.
# 그러나 어떤 것을 따쩍 보
#
# Epoch: 8/60  471/471  Error: 23.84472013806491
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 보았다.
# 이서방은 그는 어머니는 눈을 후 하고 싶아한 그의 어린다. 그는 어머니가 싶었다.
# 이애는 어머니가 선비는 머리를 하고 해 자었다.
# 이애방 어디는 듯하였다.
# 이렇게 저 그의 어머니는 것을 바라는 그의 뒤는 그런 얼굴을 바라보며 선비의 얼굴을 보며 주자의 선비의 마다가 나간다. 그는 눈을 보고 먼었다.
# 이애는 얼굴을 물라고 했다. 그는 어머니, 저
#
# Epoch: 9/60  471/471  Error: 23.33612585399634
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 보았다. 선비는 이런 뛰어 놓렸다. 그리고 멍주 영하고 나무 같이 들어 보았다. 그리고 뒤로 들어 보았다. 그리고 이 밤에 이 방을 보고 나오는 것을 바라보았다. 이서 이 방에 어머니를 하고 이 집에 없이 모음을 하고 앉아 다가 더니 하였다. 그리고 가슴을 하였다.
# 그는 이 방에 있는 듯이 일어 있다. 어서 이 집에 이 방을 보고 나무 없는 것이다.
#
# Epoch: 10/60  471/471  Error: 22.488718558564273
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 이다.
# 이 후에 그의 어머니가 그의 이를 만 치다.
# 이것이 하여 첫째는 이 없었다.
# 그리고 이 집에 모양이다.
# 그때 이 이 이었다. 이 아무다.
# 그의 어머니의 얼굴을 가 모양을 보았다.
# 신철이가 이 원을 일어지며,
# 이애 그래서 이 동을 가 없어 보았다.
# 신철이는 이렇게 이다.
# 옥점이가 선비는 이 없이 빨은 이 이 없었다.
# 그는 어머니를 하였다.
# 그
#
# Epoch: 11/60  471/471  Error: 22.48708939141673
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하여 하여 없다.
# 그리고 내가 나 내가 들어 그의 어떤 가슴이 말을 하고 나었다.
# 어머니에 그의 어머니를 돌아보았다. 그리고 옥점이를 돌아보았다.
# 아, 그리고 나간에 그리야 그렇게 어디 말을 다시 일어서 들어가까.
# 그리고 나간다.
# 이애는 벌컥 일어났다. 그리고 나오는 듯하였다.
# 그는 이렇게 모르며 이 방을 돌아보았다. 그리고 사람이 없었다.
# 그가야요?
#
# Epoch: 12/60  471/471  Error: 21.54990215299556
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하여 들여다. 그래서 그의 눈을 치었다. 그리고 말을 들었다. 그때 살을 음을 하였다.
# 그는 선비 어머니는 돌아보며 것을 만인다.
# 그래서 그의 손에서 있다.
# 그리고 오금 들었다.
# 그 보았다.
# 그래서 그 있었다. 그때 그의 손을 다시하였다. 그리고 그의 어머니는 모양을 하여 들었다. 그리고 그의 아 있는 것을 보며 이렇게 말하였다. 그리고 밤을
#
# Epoch: 13/60  471/471  Error: 21.82688880459618
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다. 그래서 그는 어머니는 그런다.
# 옥점이는 선비를 보았다. 그는 얼굴을 물하는 듯하였다. 그들이 문 오른다.
# 이서방은 할 것을 보았다.
# 그들은 한참이나 따라서 그 자기를 하고 있다가 한 아버지 않으면 아이야 오는 듯하였다. 그리고 말을 하였다.
# 그 자기를 오르르 하였다. 그리고 그는 얼굴을 하여 한 아이 손을 얻어 어오며 선비를 하여 들어오는 듯
#
# Epoch: 14/60  471/471  Error: 20.866555720356455
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 보려니, 아버지 못 모자를 가고 섰다. 그리고 나무다리는 어디서 나라나 나서 있는 것이 있는 것을 보았다. 그리고 나무다리나 나서 있어나 나오는 나무 있는 방문이 바라보며, 어머니는 잠을 감고 나왔다.
# 그래서 그는 어머니는 그의 어머니는 어떤 어머니는 어떤 가슴을 그림고 있는 것이 그는 무엇을 기어 어서 있어.
# 아부는 어디 가슴을 머니가 있다.
# 그는
#
# Epoch: 15/60  471/471  Error: 20.738927343353694
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다.
# 그는 무엇을 생각하는 듯하여 생각이 들어지는 듯하지 않고 싶어 하는 것을 수가 내었던 것이다.
# 그는 무슨 말을 다시는 말하다.
# 어머니가 그의 집이 가서 말하는 듯하였다.
# 이놈방 안문 것이 없어 왔다. 그는 너는 모양이다.
# 이렇게 중얼거리며 그리고 계집애를 꾹 붙고 아래가 어린다. 그는 어머니는 문을 매고 싶으며 이 문을 다시다.
# 신철이는
#
# Epoch: 16/60  471/471  Error: 20.526584660990423
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 들었다.
# 그는 어머니는 그의 음성이 아서워서 일어나서 저 집에 대어 이런 말이 새랑이 게 벌래 일어나는 것을 깨어 버렸다. 그는 소리를 따라서 그 집으로 나는 것이다.
# 그는 이렇게 말하였다. 그리고 소리를 이 뭐들고 보았다. 그는 방의 계집애는 머리를 한다.
# 이렇게 중정거리고 이것을 다시금 신철이는 눈을 배고 말았다. 그는 이러나는다. 그는 어머
#
# Epoch: 17/60  471/471  Error: 19.880753661587082
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 그들을 바라보았다.
# 이애 소리가 이 아무 들어 보면 하게 하여 보는 것을 보고 가서 의 이 일을 가 눈을 하고 들어가 가 동네 지라도 가 소리를 지 몰라 일어 어머니의 손을 하는 것을 보고 나, 왜 가슴이 새 뭐 어머니는 선비가 오늘 말에 가리가 아무의 집에는 얼핏 일어나게 가 아무다리 곁으로 오늘 것이다.
# 그는 어머니는 이 동네 이 있다.
# 이 방은
#
# Epoch: 18/60  471/471  Error: 20.358320419883952
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하고 가 있는 것을 보며 아무 소리가 가리며 이서방이 들어가 버리가 아니 그의 어머니는 선비를 바라보았다.
# 그는 선비의 전에 가 들어오면서 선비 어머니는 그리고 무슨 일이 방 집에 사람의 손을 보기 들을 보았다.
# 선비는 옥점이가 벌다 일어. 그래서 그는 얼굴을 생각히 보았다. 그리고 부엌 수가 자꾸 때에 나무 소리가 버리가 아니 그의 보기가 벌컥 일
#
# Epoch: 19/60  471/471  Error: 21.92074364999727
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각할 때, 그리 무엇으나 들어오니는 것이 그의 눈에 그는 무엇을 생각하며 어서 소리를 좌고 싶지 않았다. 그는 선비를 만나 들여다. 그는 비를 돌아보았다. 그리고 눈을 내지며, 어머니를 꺼여자기의 집어서 그리 무슨 말을 하니, 내 수가 없었니?
# 덕호는 얼굴을 그는 얼른 일어나 그들은 그는 눈에 있다가 아니 그의 무슨 말에는 소리를 오늘 들었다. 그리고
#
# Epoch: 20/60  471/471  Error: 19.80660785076248
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각해서 그게 아마은 이서방은 첫째가 부엌으로 나왔다.
# 선비는 머리를 숙고 돌아서 그리로 속으로 들어갔다.
# 그는 가슴이 또 하였다.
# 그러나 그는 머뭇하고 나오면 나서 있는 것을 보고 있지만 않고 그의 눈을 똑기히 울고 그러나무다시 못한 생각이 하여 돌아보며,
# 아니,
# 네전이 아보지는 않는 듯한 그는 그리고 생각하였다.
# 그러나 우는 소리를 만므로 이렇게 부
#
# Epoch: 21/60  471/471  Error: 19.1490620142147
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 입었다. 그는 이제나간다. 그리고 나무다리를 하고 들어오니 말을 보며,
# 이애 저 이 못 오는 것이 자기를 기웃었다. 그는 생각을 하고 앉으며 이엉 생각을 하며 이렇게 생각을 하고 싶은 생각이 한 이나도 그는 신철이는 그는 얼른 일어나며 그의 목에 섰다. 그는 머리를 돌아보았다. 그는 무심히 말을 하며 그의 곁으로 왔다. 그는 무심히 생각하였다.
# 그는 이
#
# Epoch: 22/60  471/471  Error: 19.459506030241077
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 먹었다.
# 신철이는 생각하며 선비를 보고 나오는 것이 웃었다.
# 선비는 이 방에 섰다.
# 이서방은 싱앗대를 하여 들어야 좋을 것이 없었다. 그리고 어디로 나오는 것이다.
# 이렇게 중얼거리며 이렇게 말하였다.
# 그리고 이루 같이 한참이나 바라보았다.
# 그리고 한참 나도 없었으면 들어간다. 그리고 앞으로 들어간다.
# 이렇게 물하고 나무꾼애가 하고 말을 한 듯이 들어온
#
# Epoch: 23/60  471/471  Error: 19.33092985322616
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각을 하고 말을 다시금.
# 그것은 아무히 빨개지며 머뭇머뭇머뭇하고 나간다. 그래서 그는 이렇게 생각하게 줄 아래가 그는 머리를 갸웃하고 머뭇머뭇하고 나간다. 그래서 안방에서도 부러한 듯하였던 것이다. 그러나 그는 얼른 일어나는 듯하였다. 그는 무엇을 생각하고 싶은 것을 바라보았다. 그리고 부엌으로 들어갔다. 그래서 그는 머리를 생각하고 머뭇머뭇하고 있는
#
# Epoch: 24/60  471/471  Error: 17.626711789656323
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하며 혹은 어머니를 좌우로 올려왔다.
# 아무꾼애 선비는 이 없는 두을 바라보았다.
# 어떻게 하여라보았다.
# 이 방 안에 가늘을 물어 들어가지고 싶었다.
# 그들은 어젯밤 일어나며 이서방의 아버지는 모자식 지금 이라고 이 안지를 않았다.
# 이 밤 지 못하고 이렇게 가져 보았다.
# 어머니는 이 원소를 보았다.
# 이 아자지 않는지 몰랐다. 그는 어머니는 그리고 선비가
#
# Epoch: 25/60  471/471  Error: 18.543737288941163
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하여 들었다.
# 그는 이 동네 같은 어머니의 간난이리 없이 없는 것을 느꼈다.
# 그는 이렇게 말았다. 그리고 무엇을 가만히 가는 것이 없는 것을 바라보았다.
# 그리고 그의 음성에 그의 어머니는 대로 보고 물어 보았다.
# 그는 무심히 일어 보고 아무는 것을 느꼈다.
# 그는 옥점이는 냉자기에 무슨 말이 없이 안 오는 것이 없이 들어가 가에게 한숨을 가슴이 물러앉으
#
# Epoch: 26/60  471/471  Error: 19.34071525541828
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 중얼거렸다. 그는 눈을 감시시 달았다. 그때에 그리 주었다.
# 그는 어머니는 그의 눈에 그는 신철이는 그의 어머니는 벌떡 일어났다. 그리고 다시 지나 않으니 그러나 어머니 곁으로 올라갔다. 그는 언제 그의 음성이 아니 아직 그런 말이 아 지나 다. 그는 어머니, 이렇게 중얼거렸다. 그리고 그러 그 마리 그들 게 집에 놓고 다시 문다 선비 어머니는 선비의
#
# Epoch: 27/60  471/471  Error: 18.312277521645832
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃었다.
# 그의 어머니의 동안으로 다시시다시 걸었다.
# 이거 가슴을 머리를 불웃으며 선비의 또 이 원소의 손을 보고 울고 싶었다.
# 옥점이는 호호 웃었다. 그의 눈이 이리 앞에 말이 아이 방문이 벌컥 일어 어린애의 계집은 어머니의 손을 새려고 그의 음성이 아직도 아무 김의 집이 못 사람은 그의 뒤를 따라서 다시시한 번이 좋아요, 어머니.
# 한참이나 생각하며 숨
#
# Epoch: 28/60  471/471  Error: 17.547771294524726
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 발 번 가 아프다. 그는 머리를 번쩍 들었다.
# 이 방 안에 가슴이 있다.
# 눈이 또 모양을 바라보며 무서 있을 앞으로 온다. 그리고 그는 머리를 숙나 들었다.
# 그러나 그 자 쓸어 보았다. 그리고 그러 보았다. 그리고 그를 보기 선비가 일 집 위를 놓고 무슨 말을 자기 때에서 소리를 돌아보며 이렇게 말을 하며, 그래 선비는 이 없이 말소리를 들어왔다.
# Epoch: 29/60  471/471  Error: 16.4673429392143
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하고 못 견하는 듯하여 하여 까지 말이 그의 어머니는 대로 이리 없이 없는 것을 보고 나온 것이 없었다. 그리고 말하면 마주 그러나 수가 없다. 그리고 그의 가슴이 휙 떠오른다. 그리고 소리가 나 말을 하니 때 저 소리를 꺼이 소리가 나오는 것을 보고 나서 있다. 그 자 안 오늘 말에 하면 못한 장보이 휙 소리를 보았다. 그리고 그의 어머니를 보았다
#
# Epoch: 30/60  471/471  Error: 18.526482539411912
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 새끼 첨 가 약간 기가 없다.
# 그러나 달라가 들여다 오는 것이 얼굴을 씻어 보고 싶은 생각하였다. 그리고 신철이는 벌써 일어나 앉은 먹은 생각이 들어지 못하였다.
# 그리고 어가 가 아 들어 보기 못 자기 가 자기를 하고 생각하였다. 옥점이는 눈을 끌어 뿌리며 눈을 꾹 감았다.
# 그러나 아까 웃음을 하였다. 그리고 눈을 둥아보았다. 신철이는 얼른 기울였다
#
# Epoch: 31/60  471/471  Error: 17.53726216117571
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 보았다. 그는 무엇을 생각하며 그만 보대하였다.
# 그는 눈을 가만히 물러앉는다.
# 그래서 머뭇머뭇하고 서서 서방 안 내가 하게 말하였다. 그리고 저편 가늘 지붕을 놓았다.
# 그리고 가서 하던 말하는 때 이놈의 음성이 선비를 바구니다.
# 이서방은 온 진 자가 가지 않은 것이 없는 듯하였다.
# 그리고 사람의 두 수는 모양을 바라보며 무심히 저편 보는 여서 사
#
# Epoch: 32/60  471/471  Error: 17.26307348582019
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 일어난다. 그리고 한숨을 푹 쉬었다. 그리고 화를 따라 왔다. 그리고 눈에 가서 그의 눈에 부시시겠수?
# 아니 그런 말이냐? 그는 가슴이 나무하면 내 있다. 그리고 그는 얼른 일 났다.
# 그는 이 동네 그는 이렇게 생각하였다. 그리고 그는 어머니는 그의 어머니가 나온다. 그는 어머니는 말은 그러나 어디 속으로 나왔다.
# 그래서 그는 이러나 그만나 그는 이렇게
#
# Epoch: 33/60  471/471  Error: 18.48487375087334
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 불렀다. 덕호는 웃어 줄 모양이다.
# 그러나 그 나 달라나 누가 아프다는 듯이 보면 말리는 체하였다. 그리 안 물었다.
# 그러나 그 나 먹었다. 그러나 그는 머리를 갸쩍 들었다.
# 그는 이렇게 웃었다. 그리고 귀여다보았다. 그리고 눈에 있었다. 그리고 그는 아프다. 그는 머리를 돌려보다.
# 선비는 거리는 게 해야.
# 어머니는 그리 안 하게 질하였다. 그리고
#
# Epoch: 34/60  471/471  Error: 16.760054179778596
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 모르는 이런 말을 하고 있으면 곁으로 올라갔다.
# 그리고 서방을 바라보며 선비의 손을 끌어 어린애들이 동네 모자나 가슴이 뛰어나온다. 옥점이는 신철이가 빙긋이 웃었다. 그리고 나무 들여물 소곤 하여 숨을 푹 쉬었다. 그리고 가시에 놓기가 아무 선비는 머리를 숙이 울쑥 가는 후에 어머니는 수만 있다. 이 원소를 바라보며 나무다리를 만정 들여 가지 못한 소
#
# Epoch: 35/60  471/471  Error: 16.813723079678635
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 한층다가 가시히 생각하였다. 그리고 신철이는 벌떡 일어나며,
# 이애 저 것이다.
# 그는 선비 어머니는 불을 맞아니 그들은 그러구!
# 그는 가슴이 한참이나 바라보았다. 그리고 그들이 바라보았다. 그리고 한숨을 가진하고 가지고 나뭇하니 가서 그들이 바라보았다. 그리고 그들이 그는 모양이다.
# 그는 언제 이 모양이 물그릇을 들어오는 것이다. 그리고 무슨 돌아들었다.
#
# Epoch: 36/60  471/471  Error: 16.16414326402308
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 이렇게 가져하니까 하는 불을 먹었다. 그때 어머니를 좌우로 나왔다. 그리고 술을 들이 나친다.
# 그는 이렇게 중얼거렸다.
# 그는 선비를 보고 두고 이 사람의 음성에서 서방
# 안으로 들어간 소리를 열고 들며 바라보았다. 그러나 그는 이렇게 중얼거렸다. 그는 머리를 번쩍 들었다.
# 이서방은 첫째의 얼굴을 서울고 나서 있을 때 다가 어디서 이 방으로 들어갔다.
#
# Epoch: 37/60  471/471  Error: 16.32690396704915
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며, 저 달걀 주겠나, 그 새 같이 그의 어머니를 보았다.
# 어머니 곁에 있는 것이다.
# 그리고 그는 이 한참이나 들어가 있다.
# 이애 그의 음성을 찌르르 하였다.
# 그러나 그것은 좀 집에서 그런 말을 하니야.
# 그 글쎄 어떤 곳에서 그들은 하는 소리나 나온 그의 어머니가 그의 어머니 곁으로 나왔다. 그리고 그 돈 눈에 감지 않으면 처음 말을 하는 듯하여
#
# Epoch: 38/60  471/471  Error: 17.00793765988604
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃음을 흔들여 보는 소리가 눈을 툭툭 뜨며 그는 얼굴을 찡그렸다.
# 신철의 곁에 그는 모양을 바라보며 그는 어제까지에 않은 어머니를 바라보며 덕호의 집에 보더니 저 앞자 그는 소리가 나오는 것을 보자꾸 않았다. 그리고 그는 가슴을 새삼스럽게 발견하였다.
# 그렇게 소리를 이며 그는 목을 느꼈다. 그리고 그만 변소 앞으로 슬려는 것을 느꼈다.
# 그는 어머니는 신
#
# Epoch: 39/60  471/471  Error: 17.239929308605785
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 일어났다.
# 그리고 어디가 아까지 아니라지 않는 것을 알지, 그렇지 않는가? 하는 생각까지 꼭 노려니다.
# 그는 어머니는 딸을 쳐다보았다. 어린애 이 어디려는 듯하고 나왔다. 그리고 우는 것을 깨달았다. 그는 어머니가 아니 그들은 모시 선비는 어느니 아직도 아니냐, 이 달아 지려나는 것을 알아 넣어 봐려 내가 아니라지나 그리고 신철이는 그의 어머니를 바라보
#
# Epoch: 40/60  471/471  Error: 16.59590672677016
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하다. 그리고 강하여 나왔다. 그리 해 보이 벌써 일시 하고 나왔다. 그는 벌컥 일어나며 이렇게 중얼거리며 이렇게 해서 못하는 소리가 나온다.
# 그는 나무꾼애는 벌떡 일어났다. 그리고 다시 수가 있다니 그려 나는다. 신철이는 빙긋이 웃었다. 그리고 나오는 듯하여 한참이나 들여다보는 선비를 바라보며 그는 어디 있다. 그리고 어떤 것을 보니면 저 밖을 하여
#
# Epoch: 41/60  471/471  Error: 16.949694244992536
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그는 변소를 한 모양이 되었다. 그는 이렇게 말하였다. 그러나 그것은 고 집에 와서 어머니는 이렇게 말하는 이것 같아 것 같았다. 그리에 어머니를 흘금 물고 물 위에 그의 손에 쥐고 싶었다. 그들은 바라보았다. 그리고 한 번 가 가 안 수가 없다. 신철이는 그의 음성에 그의 손이 그의 어머니를 대고 무슨 말이 그 방 이 벌써 무어 싱고 싶은
#
# Epoch: 42/60  471/471  Error: 16.81489987021361
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며 가슴이 찌르르 울려 다가 동네 이리 없이 없는 모양인지 절동한 사람이 없었다.
# 이 동네 앞으로 바라보았다. 그리고 어디로 바라지 못하여 보지 못한 어머니는 그 돈을 하고 들어 죽 같은 가슴이 찌끔 보다 부시시 일어나서 가 달걀을 향하여 이 뭐 짓이 한 듯이 가슴을 뜨고 돌아 것이 없었다.
# 한 그 첨지 못 꺼내 가 있으로 뛰어 보지 못 없었다.
# 그
#
# Epoch: 43/60  471/471  Error: 15.62485081809212
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 불얼거리는 게 뭐냐?
# 듣고 싶어 죽 위로 다가 그의 호호 웃었다.
# 그들은 한 번에는 소리에 그의 이 불은 농민들은 다가 그리고 대문을 그의 어머니를 비 붙들었다.
# 그는 무의식간에 그의 어머니는 비로 이 여자가 하고 울컥 안으로 다 하는 것을 느꼈다.
# 그의 어머니가 간난 가 눈을 받아 주었던 것이다. 그리고 무슨 속에 대었다.
# 한참이나 무엇을 생각하다가
#
# Epoch: 44/60  471/471  Error: 15.879317520362022
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃었다. 덕호는 귀를 따라 난 후 한 눈에 가서 이 원소라 하여 바라보았다. 그러나 어디서 하여요?
# 선비는 어머니를 돌아보며, 이놈들. 덕호는 머리를 푹 숙이 되었다. 옥점이는 아랫목을 바라보았다. 그들은 생각이 불쑥 들어오. 선비는 머리를 볼 때 하여 이엉초를 근 뿌리라지 않았다. 그는 후에 어머니를 보았다. 그리고 어떤 놈의 음성이 아서 변소 몰랐다
#
# Epoch: 45/60  471/471  Error: 15.593310391826744
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하였다.
# 그는 이 안으로 왔다. 이 이 안 물었다. 그리고 무슨 일이 있다. 그는 소리를 생각하고 끼며 아이 방 해 운 후 가만히 열고 들어 싸리 좋으면 들어갈 때문을 뜨고 싶어서 피어 번 원치는 아버지 달려 내려 먹으며 덕호의 하여기 알아, 말하였다. 그리고 다시다.
# 그는 이렇게 생각하며 앉아 있다.
# 그는 이렇게 생각하며 바구보다가 게 물을 하여
#
# Epoch: 46/60  471/471  Error: 15.553431262411317
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며, 저 앞을 똑닫하였다. 그리고 대문 편지를 살라보았다. 그리고 그를 꾹 짚고 서째 대답이 하였다. 그때마다가 아직도 아파지 못 당장에 몸이 남편 도록 잡아 줄을 하였다. 그러나 마침내 가져 들어오는 듯하여 들어오는 것 같이 가지고 이렇게 하고 이렇게 떠나지 않는 것을 알아, 저 모양이다.
# 그렇게 소리가 들어가는 것도 첫째를 바라보았다. 그리고 눈
#
# Epoch: 47/60  471/471  Error: 15.265088524716141
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 얻었다.
# 그는 이렇게 중얼거리며 그렇게 그림을 들어가 있어 준놈의 뒤를 따라 왔다. 이서방은 첫째도 이제까 하는 방으로 나왔다. 그리고 울어서 들어가지 그의 이렇게 중얼거리며 이렇게 말하며 이서방!
# 첫째는 눈치를 않고 물 누워요?
# 그의 안 버운 것이 그의 눈가지 빨히 보았다. 그리고 어디가 아프다고 왔다.
# 그리고 어디서 그의 모양이다.
# 아서 이런 말이
#
# Epoch: 48/60  471/471  Error: 15.276514208924747
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하였다. 그리고 화를 바라보았다. 그리고 손에 가지를 않고 그리고 다보를 노르르 쏟아들어 바가 밖으로부터 신철이가 오는 눈을 거지 못하였다. 그들은 어디 있다가 약간 선비를 바라보았다. 그리고 몇 번 나 가 오래 있다가 오는 것이 나서 그 담배를 따라서 그들은 호호 웃으로 들어가 가자선 가슴인 선비가 무엇을 생각하다가 아니어머니는 옥점이는 신철이는 벌컥
#
# Epoch: 49/60  471/471  Error: 14.330950708161321
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며, 내 오시우?
# 선비는 사람이 또 하며 생각하였다.
# 한 년이 있지 못하였다.
# 그때 선비는 무엇을 생각하는 것이다.
# 그는 무의식간에 그들이 불시산 그 푸른 것이 없는 것을 느꼈다.
# 선비는 그 돈을 가는 듯하여 까지 오늘 누구 하시 못 먹고 싶었다.
# 이번 선비가 수시시없이 열고 나오는 줄 아무지 말인 것 몰구 하는 것을 보이 몇 배 쥐고 있다. 그는
#
# Epoch: 50/60  471/471  Error: 14.647411614158028
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 보았다.
# 어머니.
# 옥점이는, 그러나 그 나두가 어떤 놈들이지 않으려니.
# 옥점이는 그의 발길로 누웠으려 일어나며 그래서 그는 약간 웃음을 띠며,
# 어머니.
# 옥점이는 그 푸른 하고 있는 것을 그는 소리를 따라 왔으며 귀여다.
# 나서 자가 우리 비록 배지여않게.
# 그러나 그는 어머니가 그리고 몇 번인지게 하겠으면 웬일인지 좌우간 신발 소리가 어린애같이 터인이 그러
#
# Epoch: 51/60  471/471  Error: 14.477955100427256
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 잠릴 못 서 원인데 가슴은 몹시 걸레를 기울거 누구야, 이놈의 새끼들은 쓸 하였다. 그래서 그 지붕 하였다. 그러나 그는 게 뭐냐?
# 이렇게 중얼거리며 그렇게 달저 때 덕호 바라본다. 그 두 오는 듯이 하는 소리가 버렸다. 그는 무슨 이야기를 떠시며 그 먹지 못할 것을 보며 저렇게 놀라 한 사람들이 다시 한번 나무는 이 이엉을 향하여 내었다. 그러나 그는
#
# Epoch: 52/60  471/471  Error: 14.467239029326276
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 대하겠니?
# 왜 어떤 모양이 바로 하면 수가 없어 가 가지.
# 옥점이는 놀라 하여 이렇게 가시치한 않으면 가받아요.
# 신철이는 벌써 일어나 앉았다.
# 그만 가슴이 가늘하게 하겠으니 갔다. 그리고 어떤 것을 깨어야 듯이 가지가 어디로 치며 어머니는 옥점이가 하는 생각이었다.
# 첫째는 어떤 가자리를 사라고 있어 가요, 우리! 하더니 담배 소리가 나간다. 그는 어머니
#
# Epoch: 53/60  471/471  Error: 14.500266594367686
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 보았다.
# 어머니 곁에서 다가 그릇을 들어왔다. 그리고 일어난다.
# 그는다.
# 따라나왔다. 옥점이는 편으로 들어왔다.
# 어머니가 되지를 않고 나오는 것이다.
# 첫째는 것이다.
# 그는 어머니가 들어갔다. 그래서 내어 들의 말 어라는 것이 선비를 쳐다보다가 머니 타나오는 것이다. 옥점이는 머뭇머뭇하다가 것이다. 그편은 어머니가 갑리를 않았다. 그는 어실어실 말
#
# Epoch: 54/60  471/471  Error: 14.315303908220265
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 불렀다. 그는 어머니. 그래…….
# 선비 어머니는 딸을 보니,
# 아버지 우리 둘이야…….
# 그리고 부엌 해야, 그것은 저 푸른다. 그는 무슨 일이냐.
# 난이는 웬일이며 그러집 아버들어.
# 선비는 어머니에 대답하였다. 그리고 몇 번 나게 말았다. 이런 말을 하고 생각하였다. 그리고 호미로 다리를 짚고 일어나며, 그게야! 그게 해요?
# 저것은 우리집에 보았다.
# 첫째야
#
# Epoch: 55/60  471/471  Error: 14.971415177993137
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며,
# 저 달걀이 따랐다.
# 그는 무의식간에 그의 손에 앉았다. 그리고 무슨 일이 다니, 난 후 간다. 그의 마주 그래요.
# 그는 누구간을 때는 비록 옥점 어머니는 다시 귀를 놓았다.
# 그는 무의식간에 옥점이는 그의 집은 나서 있다. 그리고 물을 것을 때,
# 마다 그런데 사람 다시금 서서 물어서 마주앉았다.
# 이제 무슨 말이 다.
# 그러나 그것은 아간다. 그
#
# Epoch: 56/60  471/471  Error: 14.100840025990763
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 잠겼다. 그 자태 그 동에 모두 같이 나오는 듯하여 한참이나 생각하였다. 그리고 호호 웃으며 들어간 선비를 바라본 그 듯한 마음이 부러웠다.
# 그럼 이리고 다시시한 듯하였다. 그래서 어디 가 아니냐 때문 냄버리는 사람들을 모르고 어젯밤 일을 보자 거리는 소리가 그리고 나온다. 그리고 그 집에 자태나 보이 떠나 물음을 한 그의 음성이 그의 눈을 끌고 살았을
# Epoch: 57/60  471/471  Error: 13.535602408411517
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃었다.
# 그는 잠시 해야 좋아요?
# 응.
# 나 턱이 부시다. 그리고 어디서 자네가 있었다.
# 이애를 거르며 옥점 어머니는 누가 어머니…… 하고 생각이 따라서 이 원소를 돌아보고 나무시워 이걸 해 보이 방의문이 따라서 이 집에 앉아 그의 손에 밤 있었다.
# 이애 사람 앞에 어디서 원을 하고 나왔다.
# 그는 이렇게 말하였다. 그러나 그것은 말 없는 것이 어디서 아
#
# Epoch: 58/60  471/471  Error: 14.084633225629688
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며, 저 달이 다음 말에 그는 난이다.
# 그리고 말하고 말을 다.
# 이서방은 헐 헐뚱하고 섰다. 그리고 그의 말을 한 이 모양을 바라보는 선비 어머니는 그는 어머니가 그의 말을 하는 신음이 다그는 소리가 그의 눈을 둥그둥 이고 말았다.
# 그리고 말을 탁 이 방에 그의 어머니를 돌아보며 이렇게 말하는 듯이 그의 얼굴을 바라니 그들이 불러 들렸다. 그리고
#
# Epoch: 59/60  471/471  Error: 13.984846603058093
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하면 기울 무슨 말을 하는 듯하였다. 그리고 소리를 하며 바자를 벗겨 놓았다.
# 그는 이렇게 말하고 쉬었다.
# 그래 큰시 함박 열었다. 그들은 이 없는 것을 바라보았다. 그는 멍하니 가려고 섬눈을 감정하였다. 그는 머리를 숙이 없었다. 이 눈에 꾹 사주 하려 올려온다. 그리고 무엇이 모양을 바라보며 옥점이를 생각하였다.
# 그는 이 안 문 이 모든 것을 바구
#
# Epoch: 60/60  471/471  Error: 14.975837489908658
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃으며,
# 어머니 곁으로 가서 그가 아부러한 듯하니까.
# 그리고 그의 손끝이 휙근 돌아보며,
# 그럼 그만 우뚝 섰다. 그리고 그의 얼굴을 쩍 들어온다.
# 이렇게 중얼거리며 그는 어실히 보았다.
# 그러자 그것은 몹시 돌아보았다.
# 고놈의 계집애 같은 일어나며 그는 머리를 숙이고 싶고 싶었다.
# 이러한 생각이 방울바라도 있수.
# 그럭 중에는 생각에 그 모양이다. 그리고
